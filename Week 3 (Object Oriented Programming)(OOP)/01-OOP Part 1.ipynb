# %% [markdown]
# # OOP Part 1

# %% [markdown]
# ## Key Points of OOP Part 1
# - Everything in python is a object.
# - To use OOP programmers can make own data types.
# - All Data Types in Python such such as List,Tuples,int,float etc all are the class and when we create variable and actually we create a object.
# - <b>Class</b> is a blueprint.Class have attributes and values or data and also have methods.
# - in python inside class fuctions are methods and outside the class fuctions.
# - <b>Object</b> is the instance fo a class.
# - <b>Constructor</b> -> When we create object of a class by default constructor body execute.Constructor is a speacial method that are execute itself when object is created.Basically constructor use in configuration related code such as connected to database etc.
# - Majic Methods in python are the speacial fuctionality methods havings super powers.

# %%
L = [1,2,3]

L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-af1f83522ab7> in <cell line: 3>()
#       1 L = [1,2,3]
#       2
# ----> 3 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s = 'hello'
s.append('x')

# %%
L = [1,2,3]
print(type(L))
# Out:
# <class 'list'>

# %%
s = [1,2,3]

# %%
# syntax to create an object

#objectname = classname()

# %%
# object literal
L = [1,2,3]

# %%
L = list()
L
# Out:
# []

# %%
s = str()
s
# Out:
# ''

# %%
# Pascal Case

#HelloWorld

# %%
#ATM Machine Functionality
class Atm:

  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.balance = 0
    #self.menu()

  def menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.balance = user_balance

    print('pin created successfully')
    self.menu()

  def change_pin():
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
      self.menu()
    else:
      print('nai karne de sakta re baba')
      self.menu()

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.balance:
        self.balance = self.balance - amount
        print('withdrawl successful.balance is',self.balance)
      else:
        print('abe garib')
    else:
      print('sale chor')
    self.menu()

# %%
obj1 = Atm()
# Out:
# 138485280407856

# %%
id(obj1)
# Out:
# 138485280407856

# %%
obj2 = Atm()
# Out:
# 138485280408912

# %%
id(obj2)
# Out:
# 138485280408912

# %%
L = [1,2,3]
len(L) # function ->bcos it is outside the list class
L.append()# method -> bcos it is inside the list class
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-6e25125f8329> in <cell line: 3>()
#       1 L = [1,2,3]
#       2 len(L) # function ->bcos it is outside the list class
# ----> 3 L.append()# method -> bcos it is inside the list class
#
# TypeError: list.append() takes exactly one argument (0 given)

# %%
class Temp:

  def __init__(self):
    print('hello')

obj = Temp()
# Out:
# hello

# %%
3/4*1/2
# Out:
# 0.375

# %%
class Fraction:

  # parameterized constructor
  def __init__(self,x,y):
    self.num = x
    self.den = y
  #__str__ method call when we print objects
  def __str__(self):
    return '{}/{}'.format(self.num,self.den)
  # when add two objects
  def __add__(self,other):
    new_num = self.num*other.den + other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)
  # when sub two objects
  def __sub__(self,other):
    new_num = self.num*other.den - other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)
  # when mul two objects
  def __mul__(self,other):
    new_num = self.num*other.num
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)
  # when div two objects
  def __truediv__(self,other):
    new_num = self.num*other.den
    new_den = self.den*other.num

    return '{}/{}'.format(new_num,new_den)
  # when decimal convert  object
  def convert_to_decimal(self):
    return self.num/self.den

# %%
fr1 = Fraction(3,4)
fr2 = Fraction(1,2)

# %%
fr1.convert_to_decimal()
# 3/4
# Out:
# 0.75

# %%
print(fr1 + fr2)
print(fr1 - fr2)
print(fr1 * fr2)
print(fr1 / fr2)
# Out:
# 10/8
# 2/8
# 3/8
# 6/4

# %%
#s1={1,2,3}
#s2={3,4,5}

#s1 + s2

# %%
print(fr1 - fr2)
# Out:
# 2/8
